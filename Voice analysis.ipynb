# %%
pip install ludwig #установка Ludwig
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas

# %%
data=pd.read_csv('voice.csv') #загрузка датасета

# %%
data
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
from ludwig.api import LudwigModel
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
#создание модели
model_definition = {
    'input_features': [
                                        {'name': 'meanfreq', 'type': 'numerical'}, 
                                        {'name': 'sd', 'type': 'numerical'}, 
                                        {'name': 'median', 'type': 'numerical'},
                                        {'name': 'Q25', 'type': 'numerical'},
                                        {'name': 'Q75', 'type': 'numerical'},
                                        {'name': 'IQR', 'type': 'numerical'},
                                        {'name': 'skew', 'type': 'numerical'},
                                        {'name': 'kurt', 'type': 'numerical'},
                                        {'name': 'sp.ent', 'type': 'numerical'},
                                        {'name': 'sfm', 'type': 'numerical'},
                                        {'name': 'mode', 'type': 'numerical'}, 
                                        {'name': 'centroid', 'type': 'numerical'}, 
                                        {'name': 'meanfun', 'type': 'numerical'}, 
                                        {'name': 'minfun', 'type': 'numerical'},
                                        {'name': 'maxfun', 'type': 'numerical'},
                                        {'name': 'meandom', 'type': 'numerical'},
                                        {'name': 'mindom', 'type': 'numerical'},
                                        {'name': 'maxdom', 'type': 'numerical'},
                                        {'name': 'dfrange', 'type': 'numerical'}
                                       ],
                    'output_features': [
                       {'name': 'modindx', 'type':'numerical'},
                       {'name': 'label', 'type': 'text', 'level': 'char'}
                    ]
}
model = LudwigModel(model_definition)#тренировка модели
train_stats = model.train(data)
